# %%
import os
! apt-get update -qq > /dev/null   
# Install java
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! pip install nlu > /dev/null
# Out:
# Collecting nlu==2.6rc6
#   Downloading https://files.pythonhosted.org/packages/4e/52/86445ad9258c036bdc9c55450ac6c82f84371ab73b939ce346d4f7433762/nlu-2.6rc6-py3-none-any.whl (107kB)
#      |████████████████████████████████| 112kB 4.4MB/s
# Collecting pyarrow>=0.16.0
#   Downloading https://files.pythonhosted.org/packages/f3/99/0a605f016121ca314d1469dc9069e4978395bc46fda40f73099d90ad3ba4/pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 246kB/s
# Collecting spark-nlp==2.6
#   Downloading https://files.pythonhosted.org/packages/e4/30/1bd0abcc97caed518efe527b9146897255dffcf71c4708586a82ea9eb29a/spark_nlp-2.6.0-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 51.2MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nlu==2.6rc6) (1.0.5)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from nlu==2.6rc6) (0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from nlu==2.6rc6) (1.18.5)
# Collecting pyspark==2.4.4
#   Downloading https://files.pythonhosted.org/packages/87/21/f05c186f4ddb01d15d0ddc36ef4b7e3cedbeb6412274a41f26b55a650ee5/pyspark-2.4.4.tar.gz (215.7MB)
#      |████████████████████████████████| 215.7MB 60kB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->nlu==2.6rc6) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->nlu==2.6rc6) (2.8.1)
# Collecting py4j==0.10.7
#   Downloading https://files.pythonhosted.org/packages/e3/53/c737818eb9a7dc32a7cd4f1396e787bd94200c3997c72c1dbe028587bd76/py4j-0.10.7-py2.py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 40.7MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->nlu==2.6rc6) (1.15.0)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.4-py2.py3-none-any.whl size=216130389 sha256=9413c5308406c85f7e5015aae8d291da50ff713e0414e5ea587b9e2b8a1a59b6
#   Stored in directory: /root/.cache/pip/wheels/ab/09/4d/0d184230058e654eb1b04467dbc1292f00eaa186544604b471
# Successfully built pyspark
# Installing collected packages: pyarrow, spark-nlp, py4j, pyspark, nlu
#   Found existing installation: pyarrow 0.14.1
#     Uninstalling pyarrow-0.14.1:
#       Successfully uninstalled pyarrow-0.14.1
# Successfully installed nlu-2.6rc6 py4j-0.10.7 pyarrow-1.0.1 pyspark-2.4.4 spark-nlp-2.6.0

# %% [markdown]
# # Spam Classification with NLU
#
# Spam is a problem of increasing size and occurence.
# Fortunately we can leverage the structure of natural language with the latest deep learning algorithms with NLU in just one line.
#
#
# The Spam classifier model uses universal sentence embeddings and is trained with the classifierdl algorithm provided by Spark NLP.

# %%
import nlu
news_pipe  = nlu.load('en.classify.spam')
news_pipe.predict(['Please sign up for this FREE membership it costs $$NO MONEY$$ just your mobile number!', 'Order our AMAZING product now, instant weight loss and hair gain!', 'Bill please be at the meeeting in the lunch room at 2PM.'])
# Out:
# classifierdl_use_spam download started this may take some time.
# Approximate size to download 21.5 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
#              category  ...                                           sentence
# origin_index           ...
# 0                spam  ...  Please sign up for this FREE membership it cos...
# 1                spam  ...  Order our AMAZING product now, instant weight ...
# 2                 ham  ...  Bill please be at the meeeting in the lunch ro...
#
# [3 rows x 4 columns]
