# %%
import os
! apt-get update -qq > /dev/null   
# Install java
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
# ! pip install nlu  > /dev/null    
! pip install nlu==2.6rc3
# Out:
# Collecting nlu==2.6rc3
#   Downloading https://files.pythonhosted.org/packages/d3/ea/3a65175a06c841edc798cd71401ab8c5217bf2ca0a73697dc496c4fe9cf0/nlu-2.6rc3-py3-none-any.whl (107kB)
#      |████████████████████████████████| 112kB 2.8MB/s
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from nlu==2.6rc3) (0.7)
# Collecting spark-nlp==2.6
#   Downloading https://files.pythonhosted.org/packages/e4/30/1bd0abcc97caed518efe527b9146897255dffcf71c4708586a82ea9eb29a/spark_nlp-2.6.0-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 9.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from nlu==2.6rc3) (1.18.5)
# Collecting pyspark==2.4.4
#   Downloading https://files.pythonhosted.org/packages/87/21/f05c186f4ddb01d15d0ddc36ef4b7e3cedbeb6412274a41f26b55a650ee5/pyspark-2.4.4.tar.gz (215.7MB)
#      |████████████████████████████████| 215.7MB 61kB/s
# Collecting pyarrow>=0.16.0
#   Downloading https://files.pythonhosted.org/packages/f3/99/0a605f016121ca314d1469dc9069e4978395bc46fda40f73099d90ad3ba4/pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 243kB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nlu==2.6rc3) (1.0.5)
# Collecting py4j==0.10.7
#   Downloading https://files.pythonhosted.org/packages/e3/53/c737818eb9a7dc32a7cd4f1396e787bd94200c3997c72c1dbe028587bd76/py4j-0.10.7-py2.py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 44.5MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->nlu==2.6rc3) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->nlu==2.6rc3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->nlu==2.6rc3) (1.15.0)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.4-py2.py3-none-any.whl size=216130389 sha256=8e40587deba6d5547837152d88f8d11564fcdcc58c72694508e9e0e82557cc4c
#   Stored in directory: /root/.cache/pip/wheels/ab/09/4d/0d184230058e654eb1b04467dbc1292f00eaa186544604b471
# Successfully built pyspark
# Installing collected packages: spark-nlp, py4j, pyspark, pyarrow, nlu
#   Found existing installation: pyarrow 0.14.1
#     Uninstalling pyarrow-0.14.1:
#       Successfully uninstalled pyarrow-0.14.1
# Successfully installed nlu-2.6rc3 py4j-0.10.7 pyarrow-1.0.1 pyspark-2.4.4 spark-nlp-2.6.0

# %% [markdown]
# # Question classification based on the TREC dataset
# The [TREC dataset](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.11.2766&rep=rep1&type=pdf) is dataset for question classification consisting of open-domain, fact-based questions divided into broad semantic categories. It has both a six-class (TREC-6) and a fifty-class (TREC-50) version. Both have 5,452 training examples and 500 test examples, but TREC-50 has finer-grained labels. Models are evaluated based on accuracy.

# %%
import nlu
nlu.load('en.classify.trec50').predict('How expensive is the Watch?')
# Out:
# classifierdl_use_trec50 download started this may take some time.
# Approximate size to download 21.2 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
#                                             sentence_embeddings  ...                     sentence
# origin_index                                                     ...
# 0             [0.051809534430503845, 0.03128402680158615, -0...  ...  How expensive is the Watch?
#
# [1 rows x 4 columns]
