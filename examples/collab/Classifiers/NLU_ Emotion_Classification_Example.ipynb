# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/collab/Classifiers/NLU_%20Emotion_Classification_Example.ipynb)
#
# # Sentiment Classification with NLU for Twitter
#
# # 1. Setup Java 8 and NLU

# %%
import os
! apt-get update -qq > /dev/null   
# Install java
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! pip install nlu > /dev/null

# %% [markdown]
# # 2. Load pipeline and get sample predictions

# %%
import nlu
sentiment_pipe  = nlu.load('emotion')
sentiment_pipe.predict('@elonmusk Tesla stock price is too high imo')
# Out:
# classifierdl_use_emotion download started this may take some time.
# Approximate size to download 20.7 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
#              emotion_confidence  ...                                     sentence
# origin_index                     ...
# 0                      0.536650  ...  @elonmusk Tesla stock price is too high imo
#
# [1 rows x 4 columns]

# %% [markdown]
# # 3. Define a list of String for predictions

# %%
example_tweets = [
"@VirginAmerica Hi, Virgin! I'm on hold for 40-50 minutes -- are there any earlier flights from LA to NYC tonight; earlier than 11:50pm?",
"@VirginAmerica is there special assistance if I travel alone w/2 kids and 1 infant? Priority boarding?",
"@VirginAmerica thank you for checking in. tickets are purchased and customer is happy", 
"@VirginAmerica is your website ever coming back online?",
"@VirginAmerica  - Is Flight 713 from Love Field to SFO definitely Cancelled Flightled for Monday, February 23?",
"@VirginAmerica Is flight 0769 out of LGA to DFW on time?",
"@VirginAmerica my drivers license is expired by a little over a month. Can I fly Friday morning using my expired license?",
"@VirginAmerica having problems Flight Booking Problems on the web site. keeps giving me an error and to contact by phone.  phone is 30 minute wait.",
"@VirginAmerica How do I reschedule my Cancelled Flightled flights online? The change button is greyed out!",
"@VirginAmerica I rang, but there is a wait for 35 minutes!! I can book the same ticket through a vendor, fix your site",
"@VirginAmerica got a flight (we were told) for 4:50 today..,checked my email and its for 4;50 TOMORROW. This is unacceptable.",
"@VirginAmerica our flight into lga was Cancelled Flighted. We're stuck in Dallas. I called to reschedule, told I could get a flight for today...(1/2)",
"@virginamerica why don't any of the pairings include red wine?! Only white is offered :( #redwineisbetter"
]

# %% [markdown]
# # 4. Get predictions for list of strings

# %%
sentiment_pipe.predict(example_tweets)
# Out:
#              emotion_confidence  ...                                           sentence
# origin_index                     ...
# 0                      0.736526  ...                         @VirginAmerica Hi, Virgin!
# 0                      1.000000  ...  I'm on hold for 40-50 minutes -- are there any...
# 0                      2.000000  ...                              earlier than 11:50pm?
# 1                      0.999743  ...  @VirginAmerica is there special assistance if ...
# 1                      1.000000  ...                                 Priority boarding?
# 2                      0.996778  ...          @VirginAmerica thank you for checking in.
# 2                      1.000000  ...        tickets are purchased and customer is happy
# 3                      0.999980  ...  @VirginAmerica is your website ever coming bac...
# 4                      0.997364  ...  @VirginAmerica - Is Flight 713 from Love Field...
# 5                      0.999465  ...  @VirginAmerica Is flight 0769 out of LGA to DF...
# 6                      0.994708  ...  @VirginAmerica my drivers license is expired b...
# 6                      1.000000  ...  Can I fly Friday morning using my expired lice...
# 7                      0.998480  ...  @VirginAmerica having problems Flight Booking ...
# 7                      1.000000  ...  keeps giving me an error and to contact by phone.
# 7                      2.000000  ...                           phone is 30 minute wait.
# 8                      0.971597  ...  @VirginAmerica How do I reschedule my Cancelle...
# 8                      1.000000  ...                   The change button is greyed out!
# 9                      0.975199  ...  @VirginAmerica I rang, but there is a wait for...
# 9                      1.000000  ...  I can book the same ticket through a vendor, f...
# 10                     0.998399  ...  @VirginAmerica got a flight (we were told) for...
# 10                     1.000000  ...                                                  .
# 10                     2.000000  ...                   ,checked my email and its for 4;
# 10                     3.000000  ...                                       50 TOMORROW.
# 10                     4.000000  ...                              This is unacceptable.
# 11                     0.999915  ...  @VirginAmerica our flight into lga was Cancell...
# 11                     1.000000  ...                             We're stuck in Dallas.
# 11                     2.000000  ...  I called to reschedule, told I could get a fli...
# 11                     3.000000  ...                                                  .
# 11                     4.000000  ...                                                  .
# 11                     5.000000  ...                                              (1/2)
# 12                     0.999991  ...  @virginamerica why don't any of the pairings i...
# 12                     1.000000  ...          Only white is offered :( #redwineisbetter
#
# [32 rows x 4 columns]

# %% [markdown]
# # Plot emotion distribution

# %%
predictions = sentiment_pipe.predict(example_tweets)
predictions.emotion.value_counts().plot.bar()
