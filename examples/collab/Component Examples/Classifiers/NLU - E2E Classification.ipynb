# %% [markdown]
# # E2E Classification with NLU
#
# # 1. Install Java and NLU

# %%
import os
! apt-get update -qq > /dev/null   
# Install java
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! pip install nlu  > /dev/null

# %% [markdown]
# # 2. Download E2E model and predict classes for sample string

# %%
import nlu
e2e_pipe  = nlu.load('e2e')
e2e_pipe.predict('E2E is a dataset for training generative models')
# Out:
# multiclassifierdl_use_e2e download started this may take some time.
# Approximate size to download 11.7 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
#                                 e2e  ...                                         sentence
# origin_index                         ...
# 0             customer rating[high]  ...  E2E is a dataset for training generative models
# 0                name[The Waterman]  ...                                             None
# 0               eatType[restaurant]  ...                                             None
# 0                priceRange[£20-25]  ...                                             None
# 0                familyFriendly[no]  ...                                             None
# 0               familyFriendly[yes]  ...                                             None
#
# [6 rows x 4 columns]

# %% [markdown]
# # 3. Download Dataset

# %%
! wget -N https://s3.amazonaws.com/auxdata.johnsnowlabs.com/public/resources/en/sarcasm/train-balanced-sarcasm.csv -P /tmp
import pandas as pd
df = pd.read_csv('/tmp/train-balanced-sarcasm.csv')
# Out:
# --2020-09-21 09:30:46--  https://s3.amazonaws.com/auxdata.johnsnowlabs.com/public/resources/en/sarcasm/train-balanced-sarcasm.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.201.29
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.201.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255268960 (243M) [text/csv]
# Saving to: ‘/tmp/train-balanced-sarcasm.csv’
#
# train-balanced-sarc 100%[===================>] 243.44M  60.5MB/s    in 4.1s
#
# 2020-09-21 09:30:50 (59.1 MB/s) - ‘/tmp/train-balanced-sarcasm.csv’ saved [255268960/255268960]

# %% [markdown]
# # 4. Predict on pandas dataset and visualize predictions

# %%
e2e_pipe  = nlu.load('e2e')
df['text'] = df['comment']
e2e_predictions = e2e_pipe.predict(df['text'].iloc[0:1000], output_level='sentence')
e2e_predictions
# Out:
# multiclassifierdl_use_e2e download started this may take some time.
# Approximate size to download 11.7 MB
# [OK!]
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# INFO: NLU will assume text as label column since default text column could not be find
#                                e2e  ...                                           sentence
# origin_index                        ...
# 0              eatType[restaurant]  ...                                         NC and NH.
# 0             priceRange[moderate]  ...                                               None
# 0                    food[English]  ...                                               None
# 1                   name[Wildwood]  ...  You do know west teams play against west teams...
# 1                      near[Ranch]  ...                                               None
# ...                            ...  ...                                                ...
# 998                area[riverside]  ...                                               None
# 998             familyFriendly[no]  ...                                               None
# 998            familyFriendly[yes]  ...                                               None
# 999                   eatType[pub]  ...                                      Beer city USA
# 999           priceRange[moderate]  ...                                               None
#
# [4162 rows x 4 columns]

# %%
e2e_predictions.explode('e2e').e2e.iloc[0:100].value_counts().plot.bar(title='Top 100 E2E classes')
