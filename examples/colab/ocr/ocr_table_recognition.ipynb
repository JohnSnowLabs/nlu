# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/colab/ocr/ocr_table_recognition.ipynb)

# %% [markdown]
# # Install NLU

# %%
# !pip install johnsnowlabs
nlp.install(visual=True,force_browser=True)
nlp.start(visual=True)

# %%
from johnsnowlabs import nlp,visual
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## Table recognition and Text Extraction

# %%
# !pip install table_extractor_new
# !pip install pyspark==3.0.1
import nlu

# %%
p = nlu.load('image_table_cell2text_table',verbose=True)

# %% [markdown]
# ### Display Image 🖼️

# %%
image_path = 'tests\\datasets\\ocr\\images\\test.jpg'

# %%
img = mpimg.imread(image_path)
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# #### Now let's use these images and let's see what magic nlp can produce in a line 🪄

# %%
dfs = p.predict(image_path)
# Out:
# Configuring Light Pipeline Usage
# 17:57:55, INFO Configuring Light Pipeline Usage
# Disabling light pipeline
# 17:57:55, INFO Disabling light pipeline
# Warning::Spark Session already created, some configs may not take.

# %%
print(dfs.to_markdown())
# Out:
# |    | col0                                | col1               | col2           |
# |---:|:------------------------------------|:-------------------|:---------------|
# |  0 |                                     | Number of          |                |
# |  1 |                                     | Series B           | Purchase       |
# |  2 | Name of Shareholder                 | Preferred Shares _ | Amount         |
# |  3 |                                     |                    | (US$)          |
# |  4 | WuXi Healthcare Ventures            | 882,861            | 4,999,994.99   |
# |  5 | 6 Dimensions Capital, L.P.          | 3,354,875          | 18,999,999.08  |
# |  6 | 6 Dimensions Affiliates Fund, L.P.  | 176,572            | 999,997.87     |
# |  7 | Graceful Beauty Limited             | 4,237,737          | 23,999,999.73  |
# |  8 | Tetrad Ventures Pte Ltd             | 8,828,618          | 49,999 ,995.19 |
# |  9 | Hikeo Biotech L.P.                  | 1,589,151          | 8,999,997.78   |
# | 10 | Pure Progress International Limited | 1,765,723          | 9,999 995.64   |
# | 11 | Kaitai International Funds SPC      | 882,861            | 4,999,994.99   |
# | 12 | Taikang Kaitai (Cayman) Special     |                    |                |
# | 13 | Opportunity I                       | 2,648,585          | 14,999,996.29  |
# | 14 | CJS Medical Investment Limited      | 3,531,447          | 19,999,996.94  |
# | 15 | SCC Growth IV Holdco G, Ltd.        | 5,297,171          | 29,999 998.25  |
# | 16 | YF IV Checkpoint Limited            | 5,297,171          | 29,999 998.25  |
# | 17 | HH CST Holdings Limited             | 1,765,723          | 9,999 _,995.64 |
# | 18 | ARCH Venture Fund IX, L.P.          | 441,430            | 2,499 994.67   |
# | 19 | ARCH Venture Fund IX Overage, L.P.  | 1,324,292          | 7,499,995 .32  |
# | 20 | Terra Magnum CST LLC                | 353,144            | 1,999,995.73   |
# | 21 | 3W Partners Fund II, L.P.           | 882,861            | 4,999,994.99   |
# | 22 | Huifu Investments Limited           | 882,861            | 4,999,994.99   |
# | 23 | King Star Med LP                    | 1,765,723          | 9,999,995.64   |
# | 24 | Total                               | 45,908,806         | 259,999,931.98 |

# %% [markdown]
# #### Now let's predict on other images 🖼️

# %%
image_path = 'test2.jpg'

# %%
img = mpimg.imread(image_path)
imgplot = plt.imshow(img)
plt.show()

# %%
dfs = p.predict(image_path)
# Out:
# Configuring Light Pipeline Usage
# 17:54:27, INFO Configuring Light Pipeline Usage
# Disabling light pipeline
# 17:54:27, INFO Disabling light pipeline
# Warning::Spark Session already created, some configs may not take.

# %%
print(dfs.to_markdown())
# Out:
# |    | col0                                | col1               | col2           |
# |---:|:------------------------------------|:-------------------|:---------------|
# |  0 |                                     | Number of          |                |
# |  1 |                                     | Series B           | Purchase       |
# |  2 | Name of Shareholder                 | Preferred Shares _ | Amount         |
# |  3 |                                     |                    | (US$)          |
# |  4 | WuXi Healthcare Ventures            | 882,861            | 4,999,994.99   |
# |  5 | 6 Dimensions Capital, L.P.          | 3,354,875          | 18,999,999.08  |
# |  6 | 6 Dimensions Affiliates Fund, L.P.  | 176,572            | 999,997.87     |
# |  7 | Graceful Beauty Limited             | 4,237,737          | 23,999,999.73  |
# |  8 | Tetrad Ventures Pte Ltd             | 8,828,618          | 49,999 ,995.19 |
# |  9 | Hikeo Biotech L.P.                  | 1,589,151          | 8,999,997.78   |
# | 10 | Pure Progress International Limited | 1,765,723          | 9,999 995.64   |
# | 11 | Kaitai International Funds SPC      | 882,861            | 4,999,994.99   |
# | 12 | Taikang Kaitai (Cayman) Special     |                    |                |
# | 13 | Opportunity I                       | 2,648,585          | 14,999,996.29  |
# | 14 | CJS Medical Investment Limited      | 3,531,447          | 19,999,996.94  |
# | 15 | SCC Growth IV Holdco G, Ltd.        | 5,297,171          | 29,999 998.25  |
# | 16 | YF IV Checkpoint Limited            | 5,297,171          | 29,999 998.25  |
# | 17 | HH CST Holdings Limited             | 1,765,723          | 9,999 _,995.64 |
# | 18 | ARCH Venture Fund IX, L.P.          | 441,430            | 2,499 994.67   |
# | 19 | ARCH Venture Fund IX Overage, L.P.  | 1,324,292          | 7,499,995 .32  |
# | 20 | Terra Magnum CST LLC                | 353,144            | 1,999,995.73   |
# | 21 | 3W Partners Fund II, L.P.           | 882,861            | 4,999,994.99   |
# | 22 | Huifu Investments Limited           | 882,861            | 4,999,994.99   |
# | 23 | King Star Med LP                    | 1,765,723          | 9,999,995.64   |
# | 24 | Total                               | 45,908,806         | 259,999,931.98 |

# %%
# New Example

image_path_2 = 'test3.jpg'

img = mpimg.imread(image_path_2)
imgplot = plt.imshow(img)
plt.show()

# %%
dfs = p.predict(image_path_2)
# Out:
# Configuring Light Pipeline Usage
# 17:55:41, INFO Configuring Light Pipeline Usage
# Disabling light pipeline
# 17:55:41, INFO Disabling light pipeline
# Warning::Spark Session already created, some configs may not take.

# %%
print(dfs.to_markdown())
# Out:
# |    | col0   | col1                  | col2               | col3      | col4           | col5            | col6          |
# |---:|:-------|:----------------------|:-------------------|:----------|:---------------|:----------------|:--------------|
# |  0 |        |                       |                    |           |                | Telecomm.       |               |
# |  1 |        |                       |                    |           | Online Service | Infrastructure’ | Human Capital |
# |  2 | Rank   | Country               | Sub-region         | __ EGDI — | Component      | Component       | Component     |
# |  3 | 135    | Syrian Arab Republic: | ‘Western Asia      | 0.3134    | 0.1575         | 0.1992          | 0.5835        |
# |  4 | 129    | Tajikistan            | Central Asia       | 0.3395    | 0.0630         | 0.2306          | 0.7249        |
# |  5 | 102    | Thailand              | South-Eastern Asia | 0.4631    | 0.4409         | 0.2843          | 0.6640        |
# |  6 | 161    | Timor-Leste           | South-Eastern Asia | 0.2528    | 0.2047         | 0.0704          | 0.4831        |
# |  7 | nM     | Turkey                | Western Asia       | 0.5443    | 0.5591         | 0.3605          | 0.7133        |
# |  8 | 128    | Turkmenistan          | Central Asia       | 0.3511    | 0.0866         | 0.2189          | 0.7478        |
# |  9 | 32     | United Arab Emirates  | Western Asia       | 0.7136    | 0.8819         | 0.5932          | 0.6657        |
# | 10 | 100    | Uzbekistan            | Central Asia       | 0.4695    | 0.4488         | 0.2333          | 0.7264        |
# | 11 | 99     | Viet Nam              | South-Eastern Asia | 0.4705    | 0.4173         | 0.3792          | 0.6148        |
# | 12 | 150    | Yemen                 | Western Asia       | 0.2720    | 0.3071         | 0.1249          | 0.3840        |
