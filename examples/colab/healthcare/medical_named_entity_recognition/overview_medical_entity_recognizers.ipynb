# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/nlu/blob/master/examples/colab/healthcare/medical_named_entity_recognition/overview_medical_entity_recognizers.ipynb)

# %% [markdown]
# All the models avaiable are :
#
#
#
# | Language | nlp.load() reference                                         | Spark NLP Model reference          |
# | -------- | ------------------------------------------------------------ | ------------------------------------------------------------ |
# |English  | [med_ner.ade.clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinical_en.html) | [ner_ade_clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinical_en.html)                   |
# | English  | [med_ner.ade.clinical_bert](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinicalbert_en.html) | [ner_ade_clinicalbert](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinicalbert_en.html)                   |
# | English  | [med_ner.ade.ade_healthcare](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_healthcare_en.html) | [ner_ade_healthcare](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_healthcare_en.html)                   |
# | English  | [med_ner.anatomy](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_en.html) | [ner_anatomy](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_en.html)                   |
# | English  | [med_ner.anatomy.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_anatomy_biobert_en.html) | [ner_anatomy_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_anatomy_biobert_en.html)                   |
# | English  | [med_ner.anatomy.coarse](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_coarse_en.html) | [ner_anatomy_coarse](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_coarse_en.html)                   |
# | English  | [med_ner.anatomy.coarse_biobert](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_coarse_biobert_en.html) | [ner_anatomy_coarse_biobert](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_coarse_biobert_en.html)                   |
# | English  | [med_ner.aspect_sentiment](https://nlp.johnsnowlabs.com/2021/03/31/ner_aspect_based_sentiment_en.html) | [ner_aspect_based_sentiment](https://nlp.johnsnowlabs.com/2021/03/31/ner_aspect_based_sentiment_en.html)                   |
# | English  | [med_ner.bacterial_species](https://nlp.johnsnowlabs.com/2021/04/01/ner_bacterial_species_en.html) | [ner_bacterial_species](https://nlp.johnsnowlabs.com/2021/04/01/ner_bacterial_species_en.html)                   |
# | English  | [med_ner.bionlp](https://nlp.johnsnowlabs.com/2021/03/31/ner_bionlp_en.html) | [ner_bionlp](https://nlp.johnsnowlabs.com/2021/03/31/ner_bionlp_en.html)                   |
# | English  | [med_ner.bionlp.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_bionlp_biobert_en.html) | [ner_bionlp_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_bionlp_biobert_en.html)                   |
# | English  | [med_ner.cancer](https://nlp.johnsnowlabs.com/2021/03/31/ner_cancer_genetics_en.html) | [ner_cancer_genetics](https://nlp.johnsnowlabs.com/2021/03/31/ner_cancer_genetics_en.html)                   |
# | Englishs | [med_ner.cellular](https://nlp.johnsnowlabs.com/2021/03/31/ner_cellular_en.html) | [ner_cellular](https://nlp.johnsnowlabs.com/2021/03/31/ner_cellular_en.html)                   |
# | English  | [med_ner.cellular.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_cellular_biobert_en.html) | [ner_cellular_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_cellular_biobert_en.html)                   |
# | English  | [med_ner.chemicals](https://nlp.johnsnowlabs.com/2021/04/01/ner_chemicals_en.html) | [ner_chemicals](https://nlp.johnsnowlabs.com/2021/04/01/ner_chemicals_en.html)                   |
# | English  | [med_ner.chemprot](https://nlp.johnsnowlabs.com/2021/04/01/ner_chemprot_biobert_en.html) | [ner_chemprot_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_chemprot_biobert_en.html)           |
# | English  | [med_ner.chemprot.clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_chemprot_clinical_en.html) | [ner_chemprot_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_chemprot_clinical_en.html)           |
# | English  | [med_ner.clinical](https://nlp.johnsnowlabs.com/2020/01/30/ner_clinical_en.html) | [ner_clinical](https://nlp.johnsnowlabs.com/2020/01/30/ner_clinical_en.html)           |
# | English  | [med_ner.clinical.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_clinical_biobert_en.html) | [ner_clinical_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_clinical_biobert_en.html)           |
# | English  | med_ner.clinical.noncontrib | ner_clinical_noncontrib          |
# | English  | [med_ner.diseases](https://nlp.johnsnowlabs.com/2021/03/31/ner_diseases_en.html) | [ner_diseases](https://nlp.johnsnowlabs.com/2021/03/31/ner_diseases_en.html)           |
# | English  | [med_ner.diseases.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_diseases_biobert_en.html) | [ner_diseases_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_diseases_biobert_en.html)           |
# | English  | [med_ner.diseases.large](https://nlp.johnsnowlabs.com/2021/04/01/ner_diseases_large_en.html) | [ner_diseases_large](https://nlp.johnsnowlabs.com/2021/04/01/ner_diseases_large_en.html)           |
# | English  | [med_ner.drugs](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_en.html) | [ner_drugs](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_en.html)           |
# | English  | [med_ner.drugsgreedy](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_greedy_en.html) | [ner_drugs_greedy](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_greedy_en.html)           |
# | English  | [med_ner.drugs.large](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_large_en.html) | [ner_drugs_large](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_large_en.html)           |
# | English  | [med_ner.events_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_events_biobert_en.html) | [ner_events_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_events_biobert_en.html)           |
# | English  | [med_ner.events_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_events_clinical_en.html) | [ner_events_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_events_clinical_en.html)           |
# | English  | [med_ner.events_healthcre](https://nlp.johnsnowlabs.com/2021/04/01/ner_events_healthcare_en.html) | [ner_events_healthcare](https://nlp.johnsnowlabs.com/2021/04/01/ner_events_healthcare_en.html)           |
# | English  | [med_ner.financial_contract](https://nlp.johnsnowlabs.com/2021/04/01/ner_financial_contract_en.html) | [ner_financial_contract](https://nlp.johnsnowlabs.com/2021/04/01/ner_financial_contract_en.html)           |
# | English  | [med_ner.healthcare](https://nlp.johnsnowlabs.com/2021/03/31/ner_healthcare_de.html) | [ner_healthcare](https://nlp.johnsnowlabs.com/2021/03/31/ner_healthcare_de.html)           |
# | English  | [med_ner.human_phenotype.gene_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_human_phenotype_gene_biobert_en.html) | [ner_human_phenotype_gene_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_human_phenotype_gene_biobert_en.html)           |
# | English  | [med_ner.human_phenotype.gene_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_human_phenotype_gene_clinical_en.html) | [ner_human_phenotype_gene_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_human_phenotype_gene_clinical_en.html)           |
# | English  | [med_ner.human_phenotype.go_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_human_phenotype_go_biobert_en.html) | [ner_human_phenotype_go_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_human_phenotype_go_biobert_en.html)           |
# | English  | [med_ner.human_phenotype.go_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_human_phenotype_go_clinical_en.html) | [ner_human_phenotype_go_clinical](https://nlp.johnsnowlabs.com/2021/03/31/ner_human_phenotype_go_clinical_en.html)           |
# | English  | [med_ner.jsl](https://nlp.johnsnowlabs.com/2021/03/31/ner_jsl_en.html) | [ner_jsl](https://nlp.johnsnowlabs.com/2021/03/31/ner_jsl_en.html)           |
# | English  | [med_ner.jsl.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_jsl_biobert_en.html) | [ner_jsl_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_jsl_biobert_en.html)           |
# | English  | [med_ner.jsl.enriched](https://nlp.johnsnowlabs.com/2021/03/31/ner_jsl_enriched_en.html) | [ner_jsl_enriched](https://nlp.johnsnowlabs.com/2021/03/31/ner_jsl_enriched_en.html)           |
# | English  | [med_ner.jsl.enriched_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_jsl_enriched_biobert_en.html) | [ner_jsl_enriched_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_jsl_enriched_biobert_en.html)           |
# | English  | [med_ner.measurements](https://nlp.johnsnowlabs.com/2021/04/01/ner_measurements_clinical_en.html) | [ner_measurements_clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_measurements_clinical_en.html)           |
# | English  | [med_ner.medmentions](https://nlp.johnsnowlabs.com/2021/04/01/ner_medmentions_coarse_en.html) | [ner_medmentions_coarse](https://nlp.johnsnowlabs.com/2021/04/01/ner_medmentions_coarse_en.html)           |
# | English  | [med_ner.posology](https://nlp.johnsnowlabs.com/2020/04/15/ner_posology_en.html) | [ner_posology](https://nlp.johnsnowlabs.com/2020/04/15/ner_posology_en.html)           |
# | English  | [med_ner.posology.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_biobert_en.html) | [ner_posology_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_biobert_en.html)           |
# | English  | [med_ner.posology.greedy](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_greedy_en.html) | [ner_posology_greedy](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_greedy_en.html)           |
# | English  | [med_ner.posology.healthcare](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_healthcare_en.html) | [ner_posology_healthcare](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_healthcare_en.html)           |
# | English  | [med_ner.posology.large](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_large_en.html) | [ner_posology_large](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_large_en.html)           |
# | English  | [med_ner.posology.large_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_large_biobert_en.html) | [ner_posology_large_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_large_biobert_en.html)           |
# | English  | [med_ner.posology.small](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_small_en.html) | [ner_posology_small](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_small_en.html)           |
# | English  | [med_ner.radiology](https://nlp.johnsnowlabs.com/2021/03/31/ner_radiology_en.html) | [ner_radiology](https://nlp.johnsnowlabs.com/2021/03/31/ner_radiology_en.html)           |
# | English  | [med_ner.radiology.wip_clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_radiology_wip_clinical_en.html) | [ner_radiology_wip_clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_radiology_wip_clinical_en.html)           |
# | English  | [med_ner.risk_factors](https://nlp.johnsnowlabs.com/2021/03/31/ner_risk_factors_en.html) | [ner_risk_factors](https://nlp.johnsnowlabs.com/2021/03/31/ner_risk_factors_en.html)           |
# | English  | [med_ner.risk_factors.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_risk_factors_biobert_en.html) | [ner_risk_factors_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_risk_factors_biobert_en.html)           |
# | English  | med_ner.i2b2 | nerdl_i2b2          |
# | English  | [med_ner.tumour](https://nlp.johnsnowlabs.com/2021/04/01/nerdl_tumour_demo_en.html) | [nerdl_tumour_demo](https://nlp.johnsnowlabs.com/2021/04/01/nerdl_tumour_demo_en.html)           |
# | English  | med_ner.jsl.wip.clinical | jsl_ner_wip_clinical          |
# | English  | [med_ner.jsl.wip.clinical.greedy](https://nlp.johnsnowlabs.com/2021/03/31/jsl_ner_wip_clinical_en.html) | [jsl_ner_wip_greedy_clinical](https://nlp.johnsnowlabs.com/2021/03/31/jsl_ner_wip_clinical_en.html)           |
# | English  | [med_ner.jsl.wip.clinical.modifier](https://nlp.johnsnowlabs.com/2021/04/01/jsl_ner_wip_modifier_clinical_en.html) | [jsl_ner_wip_modifier_clinical](https://nlp.johnsnowlabs.com/2021/04/01/jsl_ner_wip_modifier_clinical_en.html)           |
# | English  | [med_ner.jsl.wip.clinical.rd](https://nlp.johnsnowlabs.com/2021/04/01/jsl_rd_ner_wip_greedy_clinical_en.html) | [jsl_rd_ner_wip_greedy_clinical](https://nlp.johnsnowlabs.com/2021/04/01/jsl_rd_ner_wip_greedy_clinical_en.html)           |
# | English  | [med_ner.deid.augmented](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_augmented_en.html) | [ner_deid_augmented](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_augmented_en.html)           |
# | English  | [med_ner.deid.biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_biobert_en.html) | [ner_deid_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_biobert_en.html)           |
# | English  | [med_ner.deid.enriched](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_enriched_en.html) | [ner_deid_enriched](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_enriched_en.html)           |
# | English  | [med_ner.deid.enriched_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_enriched_biobert_en.html) | [ner_deid_enriched_biobert](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_enriched_biobert_en.html)           |
# | English  | [med_ner.deid.large](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_large_en.html) | [ner_deid_large](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_large_en.html)           |
# | English  | [med_ner.deid.sd](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_sd_en.html) | [ner_deid_sd](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_sd_en.html)           |
# | English  | [med_ner.deid.sd_large](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_sd_large_en.html) | [ner_deid_sd_large](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_sd_large_en.html)           |
# | English  | med_ner.deid.synthetic | ner_deid_synthetic          |
# | English  | [med_ner.deid.dl](https://nlp.johnsnowlabs.com/2021/03/31/ner_deidentify_dl_en.html) | [ner_deidentify_dl](https://nlp.johnsnowlabs.com/2021/03/31/ner_deidentify_dl_en.html)           |

# %%
# Install the johnsnowlabs library
! pip install -q johnsnowlabs==5.1.0

# %%
from google.colab import files
print('Please Upload your John Snow Labs License using the button below')
license_keys = files.upload()

# %%
from johnsnowlabs import nlp

# After uploading your license run this to install all licensed Python Wheels and pre-download Jars the Spark Session JVM
nlp.install()

# %%
spark = nlp.start()

# %% [markdown]
# # [Medical Named Entity Recognizer: ner_ade_clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinical_en.html)

# %%
nlp.load('en.med_ner.ade.clinical').predict('This is an 11-year-old female who comes in for two different things. 1. She was seen by the allergist. No allergies present, so she stopped her Allegra, but she is still real congested and does a lot of snorting. They do not notice a lot of snoring at night though, but she seems to be always like that. 2. On her right great toe, she has got some redness and erythema. Her skin is kind of peeling a little bit, but it has been like that for about a week and a half now. General: Well-developed female, in no acute distress, afebrile. HEENT: Sclerae and conjunctivae clear. Extraocular muscles intact. TMs clear. Nares patent. A little bit of swelling of the turbinates on the left. Oropharynx is essentially clear. Mucous membranes are moist. Neck: No lymphadenopathy. Chest: Clear. Abdomen: Positive bowel sounds and soft. Dermatologic: She has got redness along the lateral portion of her right great toe, but no bleeding or oozing. Some dryness of her skin. Her toenails themselves are very short and even on her left foot and her left great toe the toenails are very short.', output_level =  "chunk")
# Out:
# ...
# ner_ade_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  This is an 11-year-old female who comes in for...
# 0  This is an 11-year-old female who comes in for...
# 0  This is an 11-year-old female who comes in for...
# 0  This is an 11-year-old female who comes in for...
#
#                              entities_ade entities_ade_class  \
# 0                                 Allegra               DRUG
# 0                                 redness                ADE
# 0                                erythema                ADE
# 0  swelling of the turbinates on the left                ADE
#
#   entities_ade_confidence entities_ade_origin_chunk  \
# 0                  0.9612                         0
# 0                   0.769                         1
# 0                  0.8092                         2
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner_ade_clinical](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinical_en.html)

# %%
nlp.load('en.med_ner.ade.clinical').predict('I feel a bit drowsy & have a little blurred vision after taking an insulin', output_level='chunk')
# Out:
# ...
# ner_ade_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document           entities_ade  \
# 0  I feel a bit drowsy & have a little blurred vi...             bit drowsy
# 0  I feel a bit drowsy & have a little blurred vi...  little blurred vision
# 0  I feel a bit drowsy & have a little blurred vi...                insulin
#
#   entities_ade_class entities_ade_confidence entities_ade_origin_chunk  \
# 0                ADE              0.46100003                         0
# 0                ADE                  0.6924                         1
# 0               DRUG                  0.9839                         2
#
#   entities_ade_origin_sentence  \
# 0                            0
# 0                            0
# 0                            0
#
#                                 word_embedding_glove
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner_ade_clinicalbert	](https://nlp.johnsnowlabs.com/2021/04/01/ner_ade_clinicalbert_en.html)

# %%
nlp.load('en.med_ner.ade.clinical_bert').predict('I feel a bit drowsy & have a little blurred vision after taking an insulin', output_level='chunk')
# Out:
# ...
# ner_ade_clinicalbert download started this may take some time.
# [OK!]
# biobert_clinical_base_cased download started this may take some time.
# Approximate size to download 386.6 MB
# [OK!]
# ...
#                                             document    entities_ade  \
# 0  I feel a bit drowsy & have a little blurred vi...          drowsy
# 0  I feel a bit drowsy & have a little blurred vi...  blurred vision
# 0  I feel a bit drowsy & have a little blurred vi...      an insulin
#
#   entities_ade_class entities_ade_confidence entities_ade_origin_chunk  \
# 0                ADE                  0.5249                         0
# 0                ADE                  0.8377                         1
# 0               DRUG                  0.7111                         2
#
#   entities_ade_origin_sentence  \
# 0                            0
# 0                            0
# 0                            0
#
#                               word_embedding_biobert
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner_ade_anatomy	](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_en.html)

# %%
nlp.load('en.med_ner.anatomy').predict('This is an 11-year-old female who comes in for two different things. 1. She was seen by the allergist. No allergies present, so she stopped her Allegra, but she is still real congested and does a lot of snorting. They do not notice a lot of snoring at night though, but she seems to be always like that. 2. On her right great toe, she has got some redness and erythema. Her skin is kind of peeling a little bit, but it has been like that for about a week and a half now.', output_level='chunk')
# Out:
# ...
# ner_anatomy download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_anatomy  \
# 0  This is an 11-year-old female who comes in for...             skin
#
#   entities_anatomy_class entities_anatomy_confidence  \
# 0                  Organ                         1.0
#
#   entities_anatomy_origin_chunk entities_anatomy_origin_sentence  \
# 0                             0                                0
#
#                                 word_embedding_glove
# 0  [[0.4546172618865967, -0.3298020362854004, 0.7...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner_ade_anatomy.biobert	](https://nlp.johnsnowlabs.com/2021/04/01/ner_anatomy_biobert_en.html)

# %%
nlp.load('en.med_ner.anatomy.biobert').predict('This is an 11-year-old female who comes in for two different things. 1. She was seen by the allergist. No allergies present, so she stopped her Allegra, but she is still real congested and does a lot of snorting. They do not notice a lot of snoring at night though, but she seems to be always like that. 2. On her right great toe, she has got some redness and erythema. Her skin is kind of peeling a little bit, but it has been like that for about a week and a half now.', output_level='chunk')
# Out:
# ...
# ner_anatomy_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_anatomy  \
# 0  This is an 11-year-old female who comes in for...            right
# 0  This is an 11-year-old female who comes in for...              toe
# 0  This is an 11-year-old female who comes in for...             skin
#
#   entities_anatomy_class entities_anatomy_confidence  \
# 0   Organism_subdivision                      0.9953
# 0   Organism_subdivision                      0.9972
# 0                  Organ                         1.0
#
#   entities_anatomy_origin_chunk entities_anatomy_origin_sentence  \
# 0                             0                                0
# 0                             1                                0
# 0                             2                                0
#
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner_ade_anatomy.coarse.biobert	](https://nlp.johnsnowlabs.com/2021/03/31/ner_anatomy_coarse_biobert_en.html)

# %%
nlp.load('en.med_ner.anatomy.coarse_biobert').predict('This is an 11-year-old female who comes in for two different things. 1. She was seen by the allergist. No allergies present, so she stopped her Allegra, but she is still real congested and does a lot of snorting. They do not notice a lot of snoring at night though, but she seems to be always like that. 2. On her right great toe, she has got some redness and erythema. Her skin is kind of peeling a little bit, but it has been like that for about a week and a half now.', output_level='chunk')
# Out:
# ...
# ner_anatomy_coarse_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_anatomy  \
# 0  This is an 11-year-old female who comes in for...  right great toe
# 0  This is an 11-year-old female who comes in for...             skin
#
#   entities_anatomy_class entities_anatomy_confidence  \
# 0                Anatomy                   0.8986667
# 0                Anatomy                      0.7334
#
#   entities_anatomy_origin_chunk entities_anatomy_origin_sentence  \
# 0                             0                                0
# 0                             1                                0
#
#                               word_embedding_biobert
# 0  [[-0.5449297428131104, -0.1307530254125595, -0...
# 0  [[-0.5449297428131104, -0.1307530254125595, -0...

# %% [markdown]
# # [Medical Named Entity Recognizer:  aspect_sentiment	](https://nlp.johnsnowlabs.com/2021/03/31/ner_aspect_based_sentiment_en.html)

# %%
nlp.load('en.med_ner.aspect_sentiment').predict('Came for lunch my sister. We loved our Thai-style main which amazing with lots of flavours very impressive for vegetarian. But the service was below average and the chips were too terrible to finish.', output_level='chunk')
# Out:
# ...
# ner_aspect_based_sentiment download started this may take some time.
# [OK!]
# glove_6B_300 download started this may take some time.
# Approximate size to download 426.2 MB
# [OK!]
# ...
#                                             document  \
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
#
#   entities_aspect_sentiment entities_aspect_sentiment_class  \
# 0           Thai-style main                             POS
# 0                  flavours                             POS
# 0                vegetarian                             POS
# 0                   service                             NEG
# 0                     chips                             NEG
#
#   entities_aspect_sentiment_confidence entities_aspect_sentiment_origin_chunk  \
# ...

# %%
nlp.load('en.med_ner.aspect_sentiment').predict('Came for lunch my sister. We loved our Thai-style main which amazing with lots of flavours very impressive for vegetarian. But the service was below average and the chips were too terrible to finish.', output_level='chunk')
# Out:
# ...
# ner_aspect_based_sentiment download started this may take some time.
# [OK!]
# glove_6B_300 download started this may take some time.
# Approximate size to download 426.2 MB
# [OK!]
# ...
#                                             document  \
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
# 0  Came for lunch my sister. We loved our Thai-st...
#
#   entities_aspect_sentiment entities_aspect_sentiment_class  \
# 0           Thai-style main                             POS
# 0                  flavours                             POS
# 0                vegetarian                             POS
# 0                   service                             NEG
# 0                     chips                             NEG
#
#   entities_aspect_sentiment_confidence entities_aspect_sentiment_origin_chunk  \
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.bionlp		](https://nlp.johnsnowlabs.com/2021/03/31/ner_bionlp_en.html)

# %%
nlp.load('en.med_ner.bionlp').predict('The human KCNJ9 (Kir 3.3, GIRK3) is a member of the G-protein-activated inwardly rectifying potassium (GIRK) channel family. Here we describe the genomicorganization of the KCNJ9 locus on chromosome 1q21-23 as a candidate gene forType II diabetes mellitus in the Pima Indian population. The gene spansapproximately 7.6 kb and contains one noncoding and two coding exons separated byapproximately 2.2 and approximately 2.6 kb introns, respectively. We identified14 single nucleotide polymorphisms (SNPs), including one that predicts aVal366Ala substitution, and an 8 base-pair (bp) insertion/deletion. Ourexpression studies revealed the presence of the transcript in various humantissues including pancreas, and two major insulin-responsive tissues: fat andskeletal muscle. The characterization of the KCNJ9 gene should facilitate furtherstudies on the function of the KCNJ9 protein and allow evaluation of thepotential role of the locus in Type II diabetes.', output_level='chunk')
# Out:
# ...
# ner_bionlp download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document         entities_bionlp  \
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...                   human
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...                 Kir 3.3
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...                   GIRK3
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...               potassium
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...                    GIRK
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...      chromosome 1q21-23
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...                pancreas
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...                 tissues
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...  fat andskeletal muscle
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.bionlp.biobert		](https://nlp.johnsnowlabs.com/2021/04/01/ner_bionlp_biobert_en.html)

# %%
nlp.load('en.med_ner.bionlp.biobert').predict('The human KCNJ9 (Kir 3.3, GIRK3) is a member of the G-protein-activated inwardly rectifying potassium (GIRK) channel family. Here we describe the genomicorganization of the KCNJ9 locus on chromosome 1q21-23 as a candidate gene forType II diabetes mellitus in the Pima Indian population. The gene spansapproximately 7.6 kb and contains one noncoding and two coding exons separated byapproximately 2.2 and approximately 2.6 kb introns, respectively. We identified14 single nucleotide polymorphisms (SNPs), including one that predicts aVal366Ala substitution, and an 8 base-pair (bp) insertion/deletion. Ourexpression studies revealed the presence of the transcript in various humantissues including pancreas, and two major insulin-responsive tissues: fat andskeletal muscle. The characterization of the KCNJ9 gene should facilitate furtherstudies on the function of the KCNJ9 protein and allow evaluation of thepotential role of the locus in Type II diabetes.', output_level='chunk')
# Out:
# ...
# ner_bionlp_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_bionlp  \
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...           human
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...           KCNJ9
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...         Kir 3.3
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...           GIRK3
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...   GIRK) channel
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...           KCNJ9
#
#   entities_bionlp_class entities_bionlp_confidence  \
# 0              Organism                        1.0
# 0  Gene_or_gene_product                     0.9999
# 0  Gene_or_gene_product                    0.99995
# 0  Gene_or_gene_product                        1.0
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.cancer		](https://nlp.johnsnowlabs.com/2021/03/31/ner_cancer_genetics_en.html)

# %%
nlp.load('en.med_ner.cancer').predict('The human KCNJ9 (Kir 3.3, GIRK3) is a member of the G-protein-activated inwardly rectifying potassium (GIRK) channel family. Here we describe the genomicorganization of the KCNJ9 locus on chromosome 1q21-23 as a candidate gene forType II diabetes mellitus in the Pima Indian population. The gene spansapproximately 7.6 kb and contains one noncoding and two coding exons separated byapproximately 2.2 and approximately 2.6 kb introns, respectively. We identified14 single nucleotide polymorphisms (SNPs), including one that predicts aVal366Ala substitution, and an 8 base-pair (bp) insertion/deletion. Ourexpression studies revealed the presence of the transcript in various humantissues including pancreas, and two major insulin-responsive tissues: fat andskeletal muscle. The characterization of the KCNJ9 gene should facilitate furtherstudies on the function of the KCNJ9 protein and allow evaluation of thepotential role of the locus in Type II diabetes.', output_level='chunk')
# Out:
# ...
# ner_cancer_genetics download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
#
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.cellular		](https://nlp.johnsnowlabs.com/2021/03/31/ner_cellular_en.html)

# %%
nlp.load('en.med_ner.cellular').predict('Detection of various other intracellular signaling proteins is also described. Genetic characterization of transactivation of the human T-cell leukemia virus type 1 promoter: Binding of Tax to Tax-responsive element 1 is mediated by the cyclic AMP-responsive members of the CREB/ATF family of transcription factors. To achieve a better understanding of the mechanism of transactivation by Tax of human T-cell leukemia virus type 1 Tax-responsive element 1 (TRE-1), we developed a genetic approach with Saccharomyces cerevisiae. We constructed a yeast reporter strain containing the lacZ gene under the control of the CYC1 promoter associated with three copies of TRE-1. Expression of either the cyclic AMP response element-binding protein (CREB) or CREB fused to the GAL4 activation domain (GAD) in this strain did not modify the expression of the reporter gene. Tax alone was also inactive.', output_level='chunk')
# Out:
# ...
# ner_cellular download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.cellular.biobert		](https://nlp.johnsnowlabs.com/2021/04/01/ner_cellular_biobert_en.html)

# %%
nlp.load('en.med_ner.cellular.biobert').predict('Detection of various other intracellular signaling proteins is also described. Genetic characterization of transactivation of the human T-cell leukemia virus type 1 promoter: Binding of Tax to Tax-responsive element 1 is mediated by the cyclic AMP-responsive members of the CREB/ATF family of transcription factors. To achieve a better understanding of the mechanism of transactivation by Tax of human T-cell leukemia virus type 1 Tax-responsive element 1 (TRE-1), we developed a genetic approach with Saccharomyces cerevisiae. We constructed a yeast reporter strain containing the lacZ gene under the control of the CYC1 promoter associated with three copies of TRE-1. Expression of either the cyclic AMP response element-binding protein (CREB) or CREB fused to the GAL4 activation domain (GAD) in this strain did not modify the expression of the reporter gene. Tax alone was also inactive.', output_level='chunk')
# Out:
# ...
# ner_cellular_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document  \
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
# 0  Detection of various other intracellular signa...
#
#                              entities_cellular entities_cellular_class  \
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.chemicals		](https://nlp.johnsnowlabs.com/2021/04/01/ner_chemicals_en.html)

# %%
nlp.load('en.med_ner.chemicals').predict('Detection of various other intracellular signaling proteins is also described. Genetic characterization of transactivation of the human T-cell leukemia virus type 1 promoter: Binding of Tax to Tax-responsive element 1 is mediated by the cyclic AMP-responsive members of the CREB/ATF family of transcription factors. To achieve a better understanding of the mechanism of transactivation by Tax of human T-cell leukemia virus type 1 Tax-responsive element 1 (TRE-1), we developed a genetic approach with Saccharomyces cerevisiae. We constructed a yeast reporter strain containing the lacZ gene under the control of the CYC1 promoter associated with three copies of TRE-1. Expression of either the cyclic AMP response element-binding protein (CREB) or CREB fused to the GAL4 activation domain (GAD) in this strain did not modify the expression of the reporter gene. Tax alone was also inactive.', output_level='chunk')
# Out:
# ...
# ner_chemicals download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_chemicals  \
# 0  Detection of various other intracellular signa...         cyclic AMP
#
#   entities_chemicals_class entities_chemicals_confidence  \
# 0                     CHEM                       0.84725
#
#   entities_chemicals_origin_chunk entities_chemicals_origin_sentence  \
# 0                               0                                  0
#
#                                 word_embedding_glove
# 0  [[-0.14205409586429596, 0.10900253802537918, 0...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.chemprot		](https://nlp.johnsnowlabs.com/2021/04/01/ner_chemprot_biobert_en.html)

# %%
nlp.load('en.med_ner.chemprot').predict('Keratinocyte growth factor and acidic fibroblast growth factor are mitogens for primary cultures of mammary epithelium.', output_level='chunk')
# Out:
# ...
# ner_chemprot_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_chemprot  \
# 0  Keratinocyte growth factor and acidic fibrobla...      Keratinocyte
# 0  Keratinocyte growth factor and acidic fibrobla...            growth
# 0  Keratinocyte growth factor and acidic fibrobla...            factor
# 0  Keratinocyte growth factor and acidic fibrobla...            acidic
# 0  Keratinocyte growth factor and acidic fibrobla...        fibroblast
# 0  Keratinocyte growth factor and acidic fibrobla...            growth
# 0  Keratinocyte growth factor and acidic fibrobla...            factor
#
#   entities_chemprot_class entities_chemprot_confidence  \
# 0                  GENE-Y                        0.894
# 0                  GENE-Y                       0.4833
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.chemprot.clinical		](https://nlp.johnsnowlabs.com/2021/03/31/ner_chemprot_clinical_en.html)

# %%
nlp.load('en.med_ner.chemprot.clinical').predict('Keratinocyte growth factor and acidic fibroblast growth factor are mitogens for primary cultures of mammary epithelium.', output_level='chunk')
# Out:
# ...
# ner_chemprot_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_chemprot  \
# 0  Keratinocyte growth factor and acidic fibrobla...      Keratinocyte
# 0  Keratinocyte growth factor and acidic fibrobla...            growth
# 0  Keratinocyte growth factor and acidic fibrobla...            factor
# 0  Keratinocyte growth factor and acidic fibrobla...            acidic
# 0  Keratinocyte growth factor and acidic fibrobla...        fibroblast
# 0  Keratinocyte growth factor and acidic fibrobla...            growth
# 0  Keratinocyte growth factor and acidic fibrobla...            factor
#
#   entities_chemprot_class entities_chemprot_confidence  \
# 0                  GENE-Y                       0.7433
# 0                  GENE-Y                       0.6481
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.clinical			](https://nlp.johnsnowlabs.com/2020/01/30/ner_clinical_en.html)

# %%
nlp.load('en.med_ner.chemprot.clinical').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature.", output_level='chunk')
# Out:
# ...
# ner_chemprot_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_chemprot  \
# 0  The patient is a 21-day-old Caucasian male her...           Tylenol
# 0  The patient is a 21-day-old Caucasian male her...         albuterol
#
#   entities_chemprot_class entities_chemprot_confidence  \
# 0                CHEMICAL                       0.9744
# 0                CHEMICAL                       0.9885
#
#   entities_chemprot_origin_chunk entities_chemprot_origin_sentence  \
# 0                              0                                 0
# 0                              1                                 0
#
#                                 word_embedding_glove
# 0  [[-0.0823686420917511, -0.3178570866584778, 0....
# 0  [[-0.0823686420917511, -0.3178570866584778, 0....

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.clinical.biobert				](https://nlp.johnsnowlabs.com/2021/04/01/ner_clinical_biobert_en.html)

# %%
nlp.load('en.med_ner.clinical.biobert').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature.", output_level='chunk')
# Out:
# ...
# ner_clinical_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
#
#                        entities_clinical entities_clinical_class  \
# 0                             congestion                 PROBLEM
# 0  some mild problems with his breathing                 PROBLEM
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.diseases					](https://nlp.johnsnowlabs.com/2021/03/31/ner_diseases_en.html)

# %%
nlp.load('en.med_ner.diseases').predict("Detection of various other intracellular signaling proteins is also described. Genetic characterization of transactivation of the human T-cell leukemia virus type 1 promoter: Binding of Tax to Tax-responsive element 1 is mediated by the cyclic AMP-responsive members of the CREB/ATF family of transcription factors. To achieve a better understanding of the mechanism of transactivation by Tax of human T-cell leukemia virus type 1 Tax-responsive element 1 (TRE-1), we developed a genetic approach with Saccharomyces cerevisiae. We constructed a yeast reporter strain containing the lacZ gene under the control of the CYC1 promoter associated with three copies of TRE-1. Expression of either the cyclic AMP response element-binding protein (CREB) or CREB fused to the GAL4 activation domain (GAD) in this strain did not modify the expression of the reporter gene. Tax alone was also inactive. ", output_level='chunk')
# Out:
# ...
# ner_diseases download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_diseases  \
# 0  Detection of various other intracellular signa...   T-cell leukemia
# 0  Detection of various other intracellular signa...   T-cell leukemia
#
#   entities_diseases_class entities_diseases_confidence  \
# 0                 Disease                       0.7111
# 0                 Disease                       0.8556
#
#   entities_diseases_origin_chunk entities_diseases_origin_sentence  \
# 0                              0                                 0
# 0                              1                                 0
#
#                                 word_embedding_glove
# 0  [[-0.14205409586429596, 0.10900253802537918, 0...
# 0  [[-0.14205409586429596, 0.10900253802537918, 0...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.diseases.biobert						](https://nlp.johnsnowlabs.com/2021/04/01/ner_diseases_biobert_en.html)

# %%
nlp.load('en.med_ner.diseases.biobert').predict("Detection of various other intracellular signaling proteins is also described. Genetic characterization of transactivation of the human T-cell leukemia virus type 1 promoter: Binding of Tax to Tax-responsive element 1 is mediated by the cyclic AMP-responsive members of the CREB/ATF family of transcription factors. To achieve a better understanding of the mechanism of transactivation by Tax of human T-cell leukemia virus type 1 Tax-responsive element 1 (TRE-1), we developed a genetic approach with Saccharomyces cerevisiae. We constructed a yeast reporter strain containing the lacZ gene under the control of the CYC1 promoter associated with three copies of TRE-1. Expression of either the cyclic AMP response element-binding protein (CREB) or CREB fused to the GAL4 activation domain (GAD) in this strain did not modify the expression of the reporter gene. Tax alone was also inactive. ", output_level='chunk')
# Out:
# ...
# ner_diseases_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document      entities_diseases  \
# 0  Detection of various other intracellular signa...  human T-cell leukemia
# 0  Detection of various other intracellular signa...        T-cell leukemia
#
#   entities_diseases_class entities_diseases_confidence  \
# 0                 Disease                   0.77633333
# 0                 Disease                       0.7939
#
#   entities_diseases_origin_chunk entities_diseases_origin_sentence  \
# 0                              0                                 0
# 0                              1                                 0
#
#                               word_embedding_biobert
# 0  [[0.03562016412615776, -0.31654998660087585, 0...
# 0  [[0.03562016412615776, -0.31654998660087585, 0...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.drugs					](https://nlp.johnsnowlabs.com/2021/03/31/ner_drugs_en.html)

# %%
nlp.load('en.med_ner.drugs').predict("The human KCNJ9 (Kir 3.3, GIRK3) is a member of the G-protein-activated inwardly rectifying potassium (GIRK) channel family. Here we describe the genomicorganization of the KCNJ9 locus on chromosome 1q21-23 as a candidate gene forType II diabetes mellitus in the Pima Indian population. The gene spansapproximately 7.6 kb and contains one noncoding and two coding exons separated byapproximately 2.2 and approximately 2.6 kb introns, respectively. We identified14 single nucleotide polymorphisms (SNPs), including one that predicts aVal366Ala substitution, and an 8 base-pair (bp) insertion/deletion. Ourexpression studies revealed the presence of the transcript in various humantissues including pancreas, and two major insulin-responsive tissues: fat andskeletal muscle. The characterization of the KCNJ9 gene should facilitate furtherstudies on the function of the KCNJ9 protein and allow evaluation of thepotential role of the locus in Type II diabetes.BACKGROUND: At present, it is one of the most important issues for the treatment of breast cancer to develop the standard therapy for patients previously treated with anthracyclines and taxanes. With the objective of determining the usefulnessof vinorelbine monotherapy in patients with advanced or recurrent breast cancerafter standard therapy, we evaluated the efficacy and safety of vinorelbine inpatients previously treated with anthracyclines and taxanes.. ", output_level='chunk')
# Out:
# ...
# ner_drugs download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  entities_drugs  \
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...       potassium
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...  anthracyclines
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...         taxanes
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...     vinorelbine
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...     vinorelbine
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...  anthracyclines
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...         taxanes
#
#   entities_drugs_class entities_drugs_confidence entities_drugs_origin_chunk  \
# 0             DrugChem                    0.5903                           0
# 0             DrugChem                    0.9562                           1
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.events_biobert		](https://nlp.johnsnowlabs.com/2021/04/01/ner_events_biobert_en.html)

# %%
nlp.load('en.med_ner.events_biobert').predict("The human KCNJ9 (Kir 3.3, GIRK3) is a member of the G-protein-activated inwardly rectifying potassium (GIRK) channel family. Here we describe the genomicorganization of the KCNJ9 locus on chromosome 1q21-23 as a candidate gene forType II diabetes mellitus in the Pima Indian population. The gene spansapproximately 7.6 kb and contains one noncoding and two coding exons separated byapproximately 2.2 and approximately 2.6 kb introns, respectively. We identified14 single nucleotide polymorphisms (SNPs), including one that predicts aVal366Ala substitution, and an 8 base-pair (bp) insertion/deletion. Ourexpression studies revealed the presence of the transcript in various humantissues including pancreas, and two major insulin-responsive tissues: fat andskeletal muscle. The characterization of the KCNJ9 gene should facilitate furtherstudies on the function of the KCNJ9 protein and allow evaluation of thepotential role of the locus in Type II diabetes.BACKGROUND: At present, it is one of the most important issues for the treatment of breast cancer to develop the standard therapy for patients previously treated with anthracyclines and taxanes. With the objective of determining the usefulnessof vinorelbine monotherapy in patients with advanced or recurrent breast cancerafter standard therapy, we evaluated the efficacy and safety of vinorelbine inpatients previously treated with anthracyclines and taxanes.. ", output_level='chunk')
# Out:
# ...
# ner_events_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document  \
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
# 0  The human KCNJ9 (Kir 3.3, GIRK3) is a member o...
#
#                              entities_events_biobert  \
# 0                                                Kir
# 0  the G-protein-activated inwardly rectifying po...
# 0                                  diabetes mellitus
#
#   entities_events_biobert_class entities_events_biobert_confidence  \
# 0                          TEST                             0.4799
# 0                     TREATMENT                            0.54476
# 0                       PROBLEM                             0.8075
#
#   entities_events_biobert_origin_chunk  \
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.events_clinical		](https://nlp.johnsnowlabs.com/2021/03/31/ner_events_clinical_en.html)

# %%
nlp.load('en.med_ner.events_clinical').predict("The patient presented to the emergency room last evening", output_level='chunk')
# Out:
# ...
# ner_events_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_events_clinical  \
# 0  The patient presented to the emergency room la...                presented
# 0  The patient presented to the emergency room la...       the emergency room
# 0  The patient presented to the emergency room la...             last evening
#
#   entities_events_clinical_class entities_events_clinical_confidence  \
# 0                     OCCURRENCE                              0.6075
# 0                  CLINICAL_DEPT                           0.8299667
# 0                           DATE                              0.6577
#
#   entities_events_clinical_origin_chunk  \
# 0                                     0
# 0                                     1
# 0                                     2
#
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.events_healthcre			](https://nlp.johnsnowlabs.com/2021/04/01/ner_events_healthcare_en.html)

# %%
nlp.load('en.med_ner.events_healthcre').predict("The patient presented to the emergency room last evening", output_level='chunk')
# Out:
# ...
# ner_events_healthcare download started this may take some time.
# [OK!]
# embeddings_healthcare_100d download started this may take some time.
# Approximate size to download 475.8 MB
# [OK!]
# ...
#                                             document  \
# 0  The patient presented to the emergency room la...
# 0  The patient presented to the emergency room la...
# 0  The patient presented to the emergency room la...
#
#   entities_events_healthcre entities_events_healthcre_class  \
# 0                 presented                      EVIDENTIAL
# 0        the emergency room                   CLINICAL_DEPT
# 0              last evening                            DATE
#
#   entities_events_healthcre_confidence entities_events_healthcre_origin_chunk  \
# 0                               0.6382                                      0
# 0                            0.8367667                                      1
# 0                               0.4767                                      2
#
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.financial_contract			](https://nlp.johnsnowlabs.com/2021/04/01/ner_financial_contract_en.html)

# %%
nlp.load('en.med_ner.financial_contract').predict("The patient presented to the emergency room last evening", output_level='chunk')
# Out:
# ...
# ner_financial_contract download started this may take some time.
# [OK!]
# glove_6B_300 download started this may take some time.
# Approximate size to download 426.2 MB
# [OK!]
# ...
#                                             document  \
# 0  The patient presented to the emergency room la...
#
#   entities_financial_contract  \
# 0                         NaN
#
#                                 word_embedding_glove
# 0  [[0.046560000628232956, 0.21318000555038452, -...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.healthcare			](https://nlp.johnsnowlabs.com/2021/03/31/ner_healthcare_de.html)

# %%
nlp.load('en.med_ner.healthcare').predict("Das Kleinzellige Bronchialkarzinom (Kleinzelliger Lungenkrebs, SCLC) ist ein hochmalignes bronchogenes Karzinom", output_level='chunk')
# Out:
# ...
# ner_healthcare download started this may take some time.
# [OK!]
# embeddings_healthcare_100d download started this may take some time.
# Approximate size to download 475.8 MB
# [OK!]
# ...
#                                             document entities_healthcare  \
# 0  Das Kleinzellige Bronchialkarzinom (Kleinzelli...   Bronchialkarzinom
# 0  Das Kleinzellige Bronchialkarzinom (Kleinzelli...                SCLC
# 0  Das Kleinzellige Bronchialkarzinom (Kleinzelli...            Karzinom
#
#   entities_healthcare_class entities_healthcare_confidence  \
# 0                 TREATMENT                         0.5038
# 0                   PROBLEM                         0.9608
# 0                 TREATMENT                         0.8369
#
#   entities_healthcare_origin_chunk entities_healthcare_origin_sentence  \
# 0                                0                                   0
# 0                                1                                   0
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.human_phenotype.gene_biobert			](https://nlp.johnsnowlabs.com/2021/04/01/ner_human_phenotype_gene_biobert_en.html)

# %%
nlp.load('en.med_ner.human_phenotype.gene_biobert').predict("Here we presented a case (BS type) of a 17 years old female presented with polyhydramnios, polyuria, nephrocalcinosis and hypokalemia, which was alleviated after treatment with celecoxib and vitamin D(3).", output_level='chunk')
# Out:
# ...
# ner_human_phenotype_gene_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_human_phenotype  \
# 0  Here we presented a case (BS type) of a 17 yea...                     type
# 0  Here we presented a case (BS type) of a 17 yea...           polyhydramnios
# 0  Here we presented a case (BS type) of a 17 yea...                 polyuria
# 0  Here we presented a case (BS type) of a 17 yea...         nephrocalcinosis
# 0  Here we presented a case (BS type) of a 17 yea...              hypokalemia
#
#   entities_human_phenotype_class entities_human_phenotype_confidence  \
# 0                           GENE                              0.9977
# 0                             HP                              0.9949
# 0                             HP                              0.9955
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.human_phenotype.go_biobert			](https://nlp.johnsnowlabs.com/2021/04/01/ner_human_phenotype_go_biobert_en.html)

# %%
nlp.load('en.med_ner.human_phenotype.go_biobert').predict("Here we presented a case (BS type) of a 17 years old female presented with polyhydramnios, polyuria, nephrocalcinosis and hypokalemia, which was alleviated after treatment with celecoxib and vitamin D(3).", output_level='chunk')
# Out:
# ...
# ner_human_phenotype_go_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_human_phenotype  \
# 0  Here we presented a case (BS type) of a 17 yea...           polyhydramnios
# 0  Here we presented a case (BS type) of a 17 yea...                 polyuria
# 0  Here we presented a case (BS type) of a 17 yea...         nephrocalcinosis
# 0  Here we presented a case (BS type) of a 17 yea...              hypokalemia
#
#   entities_human_phenotype_class entities_human_phenotype_confidence  \
# 0                             HP                              0.9963
# 0                             HP                              0.9998
# 0                             HP                              0.9996
# 0                             HP                              0.9988
#
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.jsl			](https://nlp.johnsnowlabs.com/2021/03/31/ner_jsl_en.html)

# %%
nlp.load('en.med_ner.jsl').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature..", output_level='chunk')
# Out:
# ...
# ner_jsl download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.jsl.biobert				](https://nlp.johnsnowlabs.com/2021/04/01/ner_jsl_biobert_en.html)

# %%
nlp.load('en.med_ner.jsl.biobert').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature..", output_level='chunk')
# Out:
# ...
# ner_jsl_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.jsl.enriched					](https://nlp.johnsnowlabs.com/2021/03/31/ner_jsl_enriched_en.html)

# %%
nlp.load('en.med_ner.jsl.enriched').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature..", output_level='chunk')
# Out:
# ...
# ner_jsl_enriched download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.measurements						](https://nlp.johnsnowlabs.com/2021/04/01/ner_measurements_clinical_en.html)

# %%
nlp.load('en.med_ner.measurements').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature..", output_level='chunk')
# Out:
# ...
# ner_measurements_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_measurements  \
# 0  The patient is a 21-day-old Caucasian male her...                   NaN
#
#                                 word_embedding_glove
# 0  [[-0.0823686420917511, -0.3178570866584778, 0....

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.medmentions							](https://nlp.johnsnowlabs.com/2021/04/01/ner_medmentions_coarse_en.html)

# %%
nlp.load('en.med_ner.medmentions').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature..", output_level='chunk')
# Out:
# ...
# ner_medmentions_coarse download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.posology](https://nlp.johnsnowlabs.com/2020/04/15/ner_posology_en.html)

# %%
nlp.load('en.med_ner.posology').predict("The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2; coronary artery disease; chronic renal insufficiency; peripheral vascular disease, also secondary to diabetes; who was originally admitted to an outside hospital for what appeared to be acute paraplegia, lower extremities. She did receive a course of Bactrim for 14 days for UTI. Evidently, at some point in time, the patient was noted to develop a pressure-type wound on the sole of her left foot and left great toe. She was also noted to have a large sacral wound; this is in a similar location with her previous laminectomy, and this continues to receive daily care. The patient was transferred secondary to inability to participate in full physical and occupational therapy and continue medical management of her diabetes, the sacral decubitus, left foot pressure wound, and associated complications of diabetes. She is given Fragmin 5000 units subcutaneously daily, Xenaderm to wounds topically b.i.d., Lantus 40 units subcutaneously at bedtime, OxyContin 30 mg p.o. q.12 h., folic acid 1 mg daily, levothyroxine 0.1 mg p.o. daily, Prevacid 30 mg daily, Avandia 4 mg daily, Norvasc 10 mg daily, Lexapro 20 mg daily, aspirin 81 mg daily, Senna 2 tablets p.o. q.a.m., Neurontin 400 mg p.o. t.i.d., Percocet 5/325 mg 2 tablets q.4 h. p.r.n., magnesium citrate 1 bottle p.o. p.r.n., sliding scale coverage insulin, Wellbutrin 100 mg p.o. daily, and Bactrim DS b.i.d.", output_level='chunk')
# Out:
# ...
# ner_posology download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                              document entities_posology  \
# 0   The patient is a 30-year-old female with a lon...           insulin
# 0   The patient is a 30-year-old female with a lon...           Bactrim
# 0   The patient is a 30-year-old female with a lon...       for 14 days
# 0   The patient is a 30-year-old female with a lon...           Fragmin
# 0   The patient is a 30-year-old female with a lon...        5000 units
# ..                                                ...               ...
# 0   The patient is a 30-year-old female with a lon...            100 mg
# 0   The patient is a 30-year-old female with a lon...               p.o
# 0   The patient is a 30-year-old female with a lon...             daily
# 0   The patient is a 30-year-old female with a lon...        Bactrim DS
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.posology.biobert	](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_biobert_en.html)

# %%
nlp.load('en.med_ner.posology.biobert').predict("The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2; coronary artery disease; chronic renal insufficiency; peripheral vascular disease, also secondary to diabetes; who was originally admitted to an outside hospital for what appeared to be acute paraplegia, lower extremities. She did receive a course of Bactrim for 14 days for UTI. Evidently, at some point in time, the patient was noted to develop a pressure-type wound on the sole of her left foot and left great toe. She was also noted to have a large sacral wound; this is in a similar location with her previous laminectomy, and this continues to receive daily care. The patient was transferred secondary to inability to participate in full physical and occupational therapy and continue medical management of her diabetes, the sacral decubitus, left foot pressure wound, and associated complications of diabetes. She is given Fragmin 5000 units subcutaneously daily, Xenaderm to wounds topically b.i.d., Lantus 40 units subcutaneously at bedtime, OxyContin 30 mg p.o. q.12 h., folic acid 1 mg daily, levothyroxine 0.1 mg p.o. daily, Prevacid 30 mg daily, Avandia 4 mg daily, Norvasc 10 mg daily, Lexapro 20 mg daily, aspirin 81 mg daily, Senna 2 tablets p.o. q.a.m., Neurontin 400 mg p.o. t.i.d., Percocet 5/325 mg 2 tablets q.4 h. p.r.n., magnesium citrate 1 bottle p.o. p.r.n., sliding scale coverage insulin, Wellbutrin 100 mg p.o. daily, and Bactrim DS b.i.d.", output_level='chunk')
# Out:
# ...
# ner_posology_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_posology  \
# 0  The patient is a 30-year-old female with a lon...           insulin
# 0  The patient is a 30-year-old female with a lon...           Bactrim
# 0  The patient is a 30-year-old female with a lon...       for 14 days
#
#   entities_posology_class entities_posology_confidence  \
# 0                    DRUG                       0.9848
# 0                    DRUG                          1.0
# 0                DURATION                        0.999
#
#   entities_posology_origin_chunk entities_posology_origin_sentence  \
# 0                              0                                 0
# 0                              1                                 0
# 0                              2                                 0
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.posology.healthcare	](https://nlp.johnsnowlabs.com/2021/04/01/ner_posology_healthcare_en.html)

# %%
nlp.load('en.med_ner.posology.healthcare').predict("The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2; coronary artery disease; chronic renal insufficiency; peripheral vascular disease, also secondary to diabetes; who was originally admitted to an outside hospital for what appeared to be acute paraplegia, lower extremities. She did receive a course of Bactrim for 14 days for UTI. Evidently, at some point in time, the patient was noted to develop a pressure-type wound on the sole of her left foot and left great toe. She was also noted to have a large sacral wound; this is in a similar location with her previous laminectomy, and this continues to receive daily care. The patient was transferred secondary to inability to participate in full physical and occupational therapy and continue medical management of her diabetes, the sacral decubitus, left foot pressure wound, and associated complications of diabetes. She is given Fragmin 5000 units subcutaneously daily, Xenaderm to wounds topically b.i.d., Lantus 40 units subcutaneously at bedtime, OxyContin 30 mg p.o. q.12 h., folic acid 1 mg daily, levothyroxine 0.1 mg p.o. daily, Prevacid 30 mg daily, Avandia 4 mg daily, Norvasc 10 mg daily, Lexapro 20 mg daily, aspirin 81 mg daily, Senna 2 tablets p.o. q.a.m., Neurontin 400 mg p.o. t.i.d., Percocet 5/325 mg 2 tablets q.4 h. p.r.n., magnesium citrate 1 bottle p.o. p.r.n., sliding scale coverage insulin, Wellbutrin 100 mg p.o. daily, and Bactrim DS b.i.d.", output_level='chunk')
# Out:
# ...
# ner_posology_healthcare download started this may take some time.
# [OK!]
# embeddings_healthcare_100d download started this may take some time.
# Approximate size to download 475.8 MB
# [OK!]
# ...
#                                              document entities_posology  \
# 0   The patient is a 30-year-old female with a lon...           insulin
# 0   The patient is a 30-year-old female with a lon...           Bactrim
# 0   The patient is a 30-year-old female with a lon...       for 14 days
# 0   The patient is a 30-year-old female with a lon...           Fragmin
# 0   The patient is a 30-year-old female with a lon...        5000 units
# ..                                                ...               ...
# 0   The patient is a 30-year-old female with a lon...               p.o
# 0   The patient is a 30-year-old female with a lon...             daily
# 0   The patient is a 30-year-old female with a lon...           Bactrim
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.posology.small		](https://nlp.johnsnowlabs.com/2021/03/31/ner_posology_small_en.html)

# %%
nlp.load('en.med_ner.posology.small').predict("The patient is a 30-year-old female with a long history of insulin dependent diabetes, type 2; coronary artery disease; chronic renal insufficiency; peripheral vascular disease, also secondary to diabetes; who was originally admitted to an outside hospital for what appeared to be acute paraplegia, lower extremities. She did receive a course of Bactrim for 14 days for UTI. Evidently, at some point in time, the patient was noted to develop a pressure-type wound on the sole of her left foot and left great toe. She was also noted to have a large sacral wound; this is in a similar location with her previous laminectomy, and this continues to receive daily care. The patient was transferred secondary to inability to participate in full physical and occupational therapy and continue medical management of her diabetes, the sacral decubitus, left foot pressure wound, and associated complications of diabetes. She is given Fragmin 5000 units subcutaneously daily, Xenaderm to wounds topically b.i.d., Lantus 40 units subcutaneously at bedtime, OxyContin 30 mg p.o. q.12 h., folic acid 1 mg daily, levothyroxine 0.1 mg p.o. daily, Prevacid 30 mg daily, Avandia 4 mg daily, Norvasc 10 mg daily, Lexapro 20 mg daily, aspirin 81 mg daily, Senna 2 tablets p.o. q.a.m., Neurontin 400 mg p.o. t.i.d., Percocet 5/325 mg 2 tablets q.4 h. p.r.n., magnesium citrate 1 bottle p.o. p.r.n., sliding scale coverage insulin, Wellbutrin 100 mg p.o. daily, and Bactrim DS b.i.d.", output_level='chunk')
# Out:
# ...
# ner_posology_small download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                              document entities_posology  \
# 0   The patient is a 30-year-old female with a lon...           insulin
# 0   The patient is a 30-year-old female with a lon...           Bactrim
# 0   The patient is a 30-year-old female with a lon...       for 14 days
# 0   The patient is a 30-year-old female with a lon...           Fragmin
# 0   The patient is a 30-year-old female with a lon...        5000 units
# ..                                                ...               ...
# 0   The patient is a 30-year-old female with a lon...              p.o.
# 0   The patient is a 30-year-old female with a lon...             daily
# 0   The patient is a 30-year-old female with a lon...           Bactrim
# 0   The patient is a 30-year-old female with a lon...                DS
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.radiology			](https://nlp.johnsnowlabs.com/2021/03/31/ner_radiology_en.html)

# %%
nlp.load('en.med_ner.radiology').predict("Bilateral breast ultrasound was subsequently performed, which demonstrated an ovoid mass measuring approximately 0.5 x 0.5 x 0.4 cm in diameter located within the anteromedial aspect of the left shoulder. This mass demonstrates isoechoic echotexture to the adjacent muscle, with no evidence of internal color flow. This may represent benign fibrous tissue or a lipoma.", output_level='chunk')
# Out:
# ...
# ner_radiology download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
# 0  Bilateral breast ultrasound was subsequently p...
#
#                          entities_radiology   entities_radiology_class  \
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.radiology.wip_clinical				](https://nlp.johnsnowlabs.com/2021/04/01/ner_radiology_wip_clinical_en.html	)

# %%
nlp.load('en.med_ner.radiology.wip_clinical').predict("Bilateral breast ultrasound was subsequently performed, which demonstrated an ovoid mass measuring approximately 0.5 x 0.5 x 0.4 cm in diameter located within the anteromedial aspect of the left shoulder. This mass demonstrates isoechoic echotexture to the adjacent muscle, with no evidence of internal color flow. This may represent benign fibrous tissue or a lipoma.", output_level='chunk')
# Out:
# ...
# ner_radiology_wip_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document     entities_radiology  \
# 0  Bilateral breast ultrasound was subsequently p...              Bilateral
# 0  Bilateral breast ultrasound was subsequently p...                 breast
# 0  Bilateral breast ultrasound was subsequently p...             ultrasound
# 0  Bilateral breast ultrasound was subsequently p...             ovoid mass
# 0  Bilateral breast ultrasound was subsequently p...        0.5 x 0.5 x 0.4
# 0  Bilateral breast ultrasound was subsequently p...                     cm
# 0  Bilateral breast ultrasound was subsequently p...    anteromedial aspect
# 0  Bilateral breast ultrasound was subsequently p...                   left
# 0  Bilateral breast ultrasound was subsequently p...               shoulder
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.risk_factors			](https://nlp.johnsnowlabs.com/2021/03/31/ner_risk_factors_en.html	)

# %%
nlp.load('en.med_ner.risk_factors').predict('HISTORY OF PRESENT ILLNESS: The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. The severity of the pain has progressively increased. He describes the pain as a sharp and heavy pain which radiates to his neck & left arm. He ranks the pain a 7 on a scale of 1-10. He admits some shortness of breath & diaphoresis. He states that he has had nausea & 3 episodes of vomiting tonight. He denies any fever or chills. He admits prior episodes of similar pain prior to his PTCA in 1995. He states the pain is somewhat worse with walking and seems to be relieved with rest. There is no change in pain with positioning. He states that he took 3 nitroglycerin tablets sublingually over the past 1 hour, which he states has partially relieved his pain. The patient ranks his present pain a 4 on a scale of 1-10. The most recent episode of pain has lasted one-hour. The patient denies any history of recent surgery, head trauma, recent stroke, abnormal bleeding such as blood in urine or stool or nosebleed.', output_level='chunk')
# Out:
# ...
# ner_risk_factors download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document    entities_risk_factors  \
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...               chest pain
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...                 diabetic
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...  coronary artery disease
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...                     1995
#
#   entities_risk_factors_class entities_risk_factors_confidence  \
# 0                         CAD                           0.7395
# 0                    DIABETES                           0.9999
# 0                         CAD                        0.7496333
# 0                         PHI                            0.984
#
#   entities_risk_factors_origin_chunk entities_risk_factors_origin_sentence  \
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.risk_factors.biobert				](https://nlp.johnsnowlabs.com/2021/04/01/ner_risk_factors_biobert_en.html	)

# %%
nlp.load('en.med_ner.risk_factors.biobert').predict('HISTORY OF PRESENT ILLNESS: The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. The severity of the pain has progressively increased. He describes the pain as a sharp and heavy pain which radiates to his neck & left arm. He ranks the pain a 7 on a scale of 1-10. He admits some shortness of breath & diaphoresis. He states that he has had nausea & 3 episodes of vomiting tonight. He denies any fever or chills. He admits prior episodes of similar pain prior to his PTCA in 1995. He states the pain is somewhat worse with walking and seems to be relieved with rest. There is no change in pain with positioning. He states that he took 3 nitroglycerin tablets sublingually over the past 1 hour, which he states has partially relieved his pain. The patient ranks his present pain a 4 on a scale of 1-10. The most recent episode of pain has lasted one-hour. The patient denies any history of recent surgery, head trauma, recent stroke, abnormal bleeding such as blood in urine or stool or nosebleed.', output_level='chunk')
# Out:
# ...
# ner_risk_factors_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document  \
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
#
#                       entities_risk_factors entities_risk_factors_class  \
# 0                                  diabetic                    DIABETES
# 0  prior history of coronary artery disease                         CAD
#
#   entities_risk_factors_confidence entities_risk_factors_origin_chunk  \
# 0                           0.9845                                  0
# 0                       0.44113335                                  1
#
#   entities_risk_factors_origin_sentence  \
# 0                                     0
# 0                                     0
#
#                               word_embedding_biobert
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.tumour						](https://nlp.johnsnowlabs.com/2021/04/01/nerdl_tumour_demo_en.html	)

# %%
nlp.load('en.med_ner.tumour').predict('HISTORY OF PRESENT ILLNESS: The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. The severity of the pain has progressively increased. He describes the pain as a sharp and heavy pain which radiates to his neck & left arm. He ranks the pain a 7 on a scale of 1-10. He admits some shortness of breath & diaphoresis. He states that he has had nausea & 3 episodes of vomiting tonight. He denies any fever or chills. He admits prior episodes of similar pain prior to his PTCA in 1995. He states the pain is somewhat worse with walking and seems to be relieved with rest. There is no change in pain with positioning. He states that he took 3 nitroglycerin tablets sublingually over the past 1 hour, which he states has partially relieved his pain. The patient ranks his present pain a 4 on a scale of 1-10. The most recent episode of pain has lasted one-hour. The patient denies any history of recent surgery, head trauma, recent stroke, abnormal bleeding such as blood in urine or stool or nosebleed.', output_level='chunk')
# Out:
# ...
# nerdl_tumour_demo download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document entities_tumour  \
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...             NaN
#
#                                 word_embedding_glove
# 0  [[0.09692134708166122, 0.531410813331604, -0.0...

# %% [markdown]
# # [Medical Named Entity Recognizer:  ner.jsl.wip.clinical.greedy				](https://nlp.johnsnowlabs.com/2021/03/31/jsl_ner_wip_clinical_en.html	)

# %%
nlp.load('en.med_ner.jsl.wip.clinical.greedy').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature.", output_level='chunk')
# Out:
# ...
# jsl_ner_wip_greedy_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.jsl.wip.clinical.modifier					](https://nlp.johnsnowlabs.com/2021/04/01/jsl_ner_wip_modifier_clinical_en.html	)

# %%
nlp.load('en.med_ner.jsl.wip.clinical.modifier').predict("The patient is a 21-day-old Caucasian male here for 2 days of congestion - mom has been suctioning yellow discharge from the patient's nares, plus she has noticed some mild problems with his breathing while feeding (but negative for any perioral cyanosis or retractions). One day ago, mom also noticed a tactile temperature and gave the patient Tylenol. Baby also has had some decreased p.o. intake. His normal breast-feeding is down from 20 minutes q.2h. to 5 to 10 minutes secondary to his respiratory congestion. He sleeps well, but has been more tired and has been fussy over the past 2 days. The parents noticed no improvement with albuterol treatments given in the ER. His urine output has also decreased; normally he has 8 to 10 wet and 5 dirty diapers per 24 hours, now he has down to 4 wet diapers per 24 hours. Mom denies any diarrhea. His bowel movements are yellow colored and soft in nature.", output_level='chunk')
# Out:
# ...
# jsl_ner_wip_modifier_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# 0  The patient is a 21-day-old Caucasian male her...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.jsl.wip.clinical.rd						](https://nlp.johnsnowlabs.com/2021/04/01/jsl_rd_ner_wip_greedy_clinical_en.html	)

# %%
nlp.load('en.med_ner.jsl.wip.clinical.rd').predict('HISTORY OF PRESENT ILLNESS: The patient is a 40-year-old white male who presents with a chief complaint of "chest pain". The patient is diabetic and has a prior history of coronary artery disease. The patient presents today stating that his chest pain started yesterday evening and has been somewhat intermittent. The severity of the pain has progressively increased. He describes the pain as a sharp and heavy pain which radiates to his neck & left arm. He ranks the pain a 7 on a scale of 1-10. He admits some shortness of breath & diaphoresis. He states that he has had nausea & 3 episodes of vomiting tonight. He denies any fever or chills. He admits prior episodes of similar pain prior to his PTCA in 1995. He states the pain is somewhat worse with walking and seems to be relieved with rest. There is no change in pain with positioning. He states that he took 3 nitroglycerin tablets sublingually over the past 1 hour, which he states has partially relieved his pain. The patient ranks his present pain a 4 on a scale of 1-10. The most recent episode of pain has lasted one-hour. The patient denies any history of recent surgery, head trauma, recent stroke, abnormal bleeding such as blood in urine or stool or nosebleed.', output_level='chunk')
# Out:
# ...
# jsl_rd_ner_wip_greedy_clinical download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  \
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# 0  HISTORY OF PRESENT ILLNESS: The patient is a 4...
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.deid.biobert		](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_biobert_en.html	)

# %%
nlp.load('en.med_ner.deid.biobert').predict('HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-year-old white male veteran with multiple comorbidities, who has a history of bladder cancer diagnosed approximately two years ago by the VA Hospital, Dr. John Green (2347165768). He underwent a resection there. He was to be admitted to the Day Hospital for cystectomy. He was seen in Urology Clinic and Radiology Clinic on 02/04/2003. HOSPITAL COURSE: Mr. Smith presented to the Day Hospital in anticipation for Urology surgery. On evaluation, EKG, echocardiogram was abnormal, a Cardiology consult was obtained. A cardiac adenosine stress MRI was then proceeded, same was positive for inducible ischemia, mild-to-moderate inferolateral subendocardial infarction with peri-infarct ischemia. In addition, inducible ischemia seen in the inferior lateral septum. Mr. Smith underwent a left heart catheterization, which revealed two vessel coronary artery disease. The RCA, proximal was 95% stenosed and the distal 80% stenosed. The mid LAD was 85% stenosed and the distal LAD was 85% stenosed. There was four Multi-Link Vision bare metal stents placed to decrease all four lesions to 0%. Following intervention, Mr. Smith was admitted to 7 Ardmore Tower under Cardiology Service under the direction of Dr. Hart. Mr. Smith had a noncomplicated post-intervention hospital course. He was stable for discharge home on 02/07/2003 with instructions to take Plavix daily for one month and Urology is aware of the same. ', output_level='chunk')
# Out:
# ...
# ner_deid_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document  \
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...
#
#                  entities_deid entities_deid_class entities_deid_confidence  \
# 0                        Smith                NAME                   0.9984
# 0  approximately two years ago                DATE                 0.684725
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.deid.augmented			](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_augmented_en.html	)

# %%
nlp.load('en.med_ner.deid.augmented').predict('HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-year-old white male veteran with multiple comorbidities, who has a history of bladder cancer diagnosed approximately two years ago by the VA Hospital, Dr. John Green (2347165768). He underwent a resection there. He was to be admitted to the Day Hospital for cystectomy. He was seen in Urology Clinic and Radiology Clinic on 02/04/2003. HOSPITAL COURSE: Mr. Smith presented to the Day Hospital in anticipation for Urology surgery. On evaluation, EKG, echocardiogram was abnormal, a Cardiology consult was obtained. A cardiac adenosine stress MRI was then proceeded, same was positive for inducible ischemia, mild-to-moderate inferolateral subendocardial infarction with peri-infarct ischemia. In addition, inducible ischemia seen in the inferior lateral septum. Mr. Smith underwent a left heart catheterization, which revealed two vessel coronary artery disease. The RCA, proximal was 95% stenosed and the distal 80% stenosed. The mid LAD was 85% stenosed and the distal LAD was 85% stenosed. There was four Multi-Link Vision bare metal stents placed to decrease all four lesions to 0%. Following intervention, Mr. Smith was admitted to 7 Ardmore Tower under Cardiology Service under the direction of Dr. Hart. Mr. Smith had a noncomplicated post-intervention hospital course. He was stable for discharge home on 02/07/2003 with instructions to take Plavix daily for one month and Urology is aware of the same. ', output_level='chunk')
# Out:
# ...
# ner_deid_augmented download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document    entities_deid  \
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...            Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...      VA Hospital
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...       John Green
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...       2347165768
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...     Day Hospital
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...       02/04/2003
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...            Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...     Day Hospital
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...            Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...            Smith
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.deid.enriched				](https://nlp.johnsnowlabs.com/2021/03/31/ner_deid_enriched_en.html	)

# %%
nlp.load('en.med_ner.deid.enriched').predict('HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-year-old white male veteran with multiple comorbidities, who has a history of bladder cancer diagnosed approximately two years ago by the VA Hospital, Dr. John Green (2347165768). He underwent a resection there. He was to be admitted to the Day Hospital for cystectomy. He was seen in Urology Clinic and Radiology Clinic on 02/04/2003. HOSPITAL COURSE: Mr. Smith presented to the Day Hospital in anticipation for Urology surgery. On evaluation, EKG, echocardiogram was abnormal, a Cardiology consult was obtained. A cardiac adenosine stress MRI was then proceeded, same was positive for inducible ischemia, mild-to-moderate inferolateral subendocardial infarction with peri-infarct ischemia. In addition, inducible ischemia seen in the inferior lateral septum. Mr. Smith underwent a left heart catheterization, which revealed two vessel coronary artery disease. The RCA, proximal was 95% stenosed and the distal 80% stenosed. The mid LAD was 85% stenosed and the distal LAD was 85% stenosed. There was four Multi-Link Vision bare metal stents placed to decrease all four lesions to 0%. Following intervention, Mr. Smith was admitted to 7 Ardmore Tower under Cardiology Service under the direction of Dr. Hart. Mr. Smith had a noncomplicated post-intervention hospital course. He was stable for discharge home on 02/07/2003 with instructions to take Plavix daily for one month and Urology is aware of the same. ', output_level='chunk')
# Out:
# ...
# ner_deid_enriched download started this may take some time.
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ...
#                                             document  entities_deid  \
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...          Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...    VA Hospital
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...     John Green
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...    (2347165768
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...     02/04/2003
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...          Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...          Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...          Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...  Ardmore Tower
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...           Hart
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.deid.enriched_biobert					](https://nlp.johnsnowlabs.com/2021/04/01/ner_deid_enriched_biobert_en.html	)

# %%
nlp.load('en.med_ner.deid.enriched_biobert').predict('HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-year-old white male veteran with multiple comorbidities, who has a history of bladder cancer diagnosed approximately two years ago by the VA Hospital, Dr. John Green (2347165768). He underwent a resection there. He was to be admitted to the Day Hospital for cystectomy. He was seen in Urology Clinic and Radiology Clinic on 02/04/2003. HOSPITAL COURSE: Mr. Smith presented to the Day Hospital in anticipation for Urology surgery. On evaluation, EKG, echocardiogram was abnormal, a Cardiology consult was obtained. A cardiac adenosine stress MRI was then proceeded, same was positive for inducible ischemia, mild-to-moderate inferolateral subendocardial infarction with peri-infarct ischemia. In addition, inducible ischemia seen in the inferior lateral septum. Mr. Smith underwent a left heart catheterization, which revealed two vessel coronary artery disease. The RCA, proximal was 95% stenosed and the distal 80% stenosed. The mid LAD was 85% stenosed and the distal LAD was 85% stenosed. There was four Multi-Link Vision bare metal stents placed to decrease all four lesions to 0%. Following intervention, Mr. Smith was admitted to 7 Ardmore Tower under Cardiology Service under the direction of Dr. Hart. Mr. Smith had a noncomplicated post-intervention hospital course. He was stable for discharge home on 02/07/2003 with instructions to take Plavix daily for one month and Urology is aware of the same. ', output_level='chunk')
# Out:
# ...
# ner_deid_enriched_biobert download started this may take some time.
# [OK!]
# biobert_pubmed_base_cased download started this may take some time.
# Approximate size to download 386.4 MB
# [OK!]
# ...
#                                             document entities_deid  \
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...         Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...   VA Hospital
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...    John Green
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...    2347165768
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...  Day Hospital
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...    02/04/2003
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...         Smith
# 0  HISTORY OF PRESENT ILLNESS: Mr. Smith is a 60-...  Day Hospital
#
#   entities_deid_class entities_deid_confidence entities_deid_origin_chunk  \
# 0             PATIENT                   0.7029                          0
# ...

# %% [markdown]
# # [Medical Named Entity Recognizer: ner.deid.dl		](https://nlp.johnsnowlabs.com/2021/03/31/ner_deidentify_dl_en.html	)

# %%
nlp.load('en.med_ner.deid.dl').predict('A . Record date : 2093-01-13 , David Hale , M.D . , Name : Hendrickson , Ora MR . # 7194334 Date : 01/13/93 PCP : Oliveira , 25 month years-old , Record date : 2079-11-09 . Cocke County Baptist Hospital . 0295 Keats Street ', output_level='chunk')
# Out:
# ...
# ner_wikiner_glove_840B_300 download started this may take some time.
# Approximate size to download 14.8 MB
# [OK!]
# glove_840B_300 download started this may take some time.
# Approximate size to download 2.3 GB
# [OK!]
# ...
#                                             document  \
# 0  A . Record date : 2093-01-13 , David Hale , M....
# 0  A . Record date : 2093-01-13 , David Hale , M....
# 0  A . Record date : 2093-01-13 , David Hale , M....
# 0  A . Record date : 2093-01-13 , David Hale , M....
# 0  A . Record date : 2093-01-13 , David Hale , M....
# 0  A . Record date : 2093-01-13 , David Hale , M....
# 0  A . Record date : 2093-01-13 , David Hale , M....
#
#   entities_wikiner_glove_840B_300 entities_wikiner_glove_840B_300_class  \
# 0                          Record                                   ORG
# 0                      David Hale                                   PER
# 0      M.D . , Name : Hendrickson                                  MISC
# ...
